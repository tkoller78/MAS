# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelBinarizer, OneHotEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Concatenate, Reshape, AveragePooling2D
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras import Input
from keras.callbacks import EarlyStopping, ModelCheckpoint
from PIL import Image
from tensorflow.keras.optimizers import Adam, RMSprop
from shutil import rmtree
from itertools import cycle
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
import seaborn as sb
import tensorflow as tf
import matplotlib.cm as cm
import re

# %% [markdown]
# # Project variables

# %%
m_name = "mobilenet_4_classes_2"
p_dir = os.path.join("../img models", m_name)

# %%
def create_dir(dir_path: str):
    if not os.path.exists(dir_path):
        os.mkdir(dir_path)

# %%
def clear_dir(dir_path: str):
    for item in os.listdir(dir_path):
        fp = os.path.join(dir_path, item)
        if os.path.isfile(fp):
            os.remove(fp)
        if os.path.isdir(fp):
            rmtree(fp)

# %%
create_dir(p_dir)
clear_dir(p_dir)

# %% [markdown]
# # Read and transform scraped dataframes

# %%
fp = "../scraped data"

channels = pd.read_pickle(os.path.join(fp, "channels.pkl"))
videos = pd.read_pickle(os.path.join(fp, "videos.pkl"))

# %%
def transform_channels(df: pd.DataFrame) -> pd.DataFrame:
    # Date string into proper date
    df.published = pd.to_datetime(df.published)
    
    # Convert field type into int64
    fields = ["video_count", "view_count"]
    df.loc[:, fields] = df.loc[:, fields].astype("int64")
    
    # Convert field type into float64
    fields = ["subscriber_count"]
    df.loc[:, fields] = df.loc[:, fields].astype("float64")
    
    # Add of channel in months
    df["age_mth"] = (pd.to_datetime("today", utc=True).year - df.published.dt.year) * 12 \
        + (pd.to_datetime("today", utc=True).month - df.published.dt.month)
        
    # Drop unnecessary fields
    df.drop(columns=["custom_url", "country"] + [c for c in df.columns if c.startswith("thumbnail")], inplace=True)
    
    # Remove channels without subscriber_count
    df = df.loc[df.subscriber_count.notnull(), :]
    
    return df

# %%
def transform_videos(df: pd.DataFrame) -> pd.DataFrame:    
    # Date string into proper date
    df.published = pd.to_datetime(df.published)
    
    # Convert field type to bool
    fields = ["broadcast"]
    df.loc[:, fields] = df.loc[:, fields].astype("bool")
    
    # Convert field type into int64
    fields = ["category_id"]
    df.loc[:, fields] = df.loc[:, fields].astype("int64")
    
    # Convert field type into float64
    fields = ["comment_count", "dislike_count", "like_count", "view_count"]
    df.loc[:, fields] = df.loc[:, fields].astype("float64")
    
    df["published_mth"] = (pd.to_datetime("today", utc=True).year - df.published.dt.year) * 12 \
        + (pd.to_datetime("today", utc=True).month - df.published.dt.month)
    df["title_len"] = df.title.str.len()
    
    df.drop(columns=["favorite_count", "broadcast", "audio_language", "comment_count", "category_id"] \
            + [c for c in df.columns if c.startswith("thumbnail")], inplace=True)
    
    df = df.loc[df.like_count.notnull() & df.dislike_count.notnull() & df.view_count.notnull(), :]
    
    return df

# %%
channels_trans = transform_channels(channels)
videos_trans = transform_videos(videos)
combo = videos_trans.merge(channels_trans[["id", "view_count","published", "age_mth", "subscriber_count",
                                             "video_count"]], 
                           how="inner", left_on="channel_id", right_on="id", suffixes=["_video", "_channel"])
combo["ln_vc_norm"] = np.log(combo.video_count / combo.subscriber_count)

# %% [markdown]
# # Define categories

# %%
cat_lbl = ["very low", "low", "high", "very high"]
combo.loc[:, "qtl"] = pd.qcut(combo.ln_vc_norm, len(cat_lbl), labels=cat_lbl, precision=6)
combo.sort_values(by=["qtl"]).qtl.hist()
plt.title("Counts of classes")
plt.show()

# %% [markdown]
# # Split dataset

# %%
y = combo.qtl
x = combo.loc[:, [c for c in combo.columns if c != "qtl"]]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=4711)

x_train.to_pickle(os.path.join(p_dir, "x_train.pkl"))
y_train.to_pickle(os.path.join(p_dir, "y_train.pkl"))
x_val.to_pickle(os.path.join(p_dir,"x_val.pkl"))
y_val.to_pickle(os.path.join(p_dir, "y_val.pkl"))
x_test.to_pickle(os.path.join(p_dir,"x_test.pkl"))
y_test.to_pickle(os.path.join(p_dir, "y_test.pkl"))

print(x_train.shape[0], x_val.shape[0], x_test.shape[0])
# Out:
# 11586 3862 3863

# %% [markdown]
# # Build the model

# %%
def create_model():
    
    inp = Input(shape=(120, 90, 3))
    
    base_model = MobileNet(weights="imagenet", include_top=False, input_tensor=inp)
    base_model.trainable = False
    x = base_model.output
    
    x = AveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Flatten()(x)
    x = Dropout(0.5)(x)
    x = Dense(200, activation="relu")(x)
    x = Dense(50, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    out = Dense(len(cat_lbl), activation="softmax")(x)
    
    model = Model(base_model.input, out)
    
    model.compile(loss='categorical_crossentropy', 
                  optimizer=Adam(learning_rate=0.0005), 
                  metrics=["accuracy"])
    
    return model

# %%
model = create_model()
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 120, 90, 3)]      0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 60, 45, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 60, 45, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 60, 45, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 60, 45, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 60, 45, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 60, 45, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 60, 45, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 60, 45, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 60, 45, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 61, 46, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 30, 22, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 30, 22, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 30, 22, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 30, 22, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 30, 22, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 30, 22, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 30, 22, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 30, 22, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 30, 22, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 30, 22, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 30, 22, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 30, 22, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 31, 23, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 15, 11, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 15, 11, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 15, 11, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 15, 11, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 15, 11, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 15, 11, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 15, 11, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 15, 11, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 15, 11, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 15, 11, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 15, 11, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 15, 11, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 16, 12, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 7, 5, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 7, 5, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 7, 5, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 7, 5, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 7, 5, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 7, 5, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 7, 5, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 7, 5, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 7, 5, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 7, 5, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 7, 5, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 7, 5, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 7, 5, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 7, 5, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 7, 5, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 7, 5, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 8, 6, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 3, 2, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 3, 2, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 3, 2, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 3, 2, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 3, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 3, 2, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 3, 2, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 3, 2, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 3, 2, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 3, 2, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 3, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 3, 2, 1024)        0
# _________________________________________________________________
# average_pooling2d_7 (Average (None, 1, 1, 1024)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 1, 1, 1024)        4096
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 200)               205000
# _________________________________________________________________
# dense_16 (Dense)             (None, 50)                10050
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 50)                200
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 204
# =================================================================
# Total params: 3,448,414
# Trainable params: 217,402
# Non-trainable params: 3,231,012
# _________________________________________________________________

# %% [markdown]
# # Prepare ImageDataGenerators

# %%
def train_generator(X, y, img_dir, batch_size):
    combo = pd.concat([X, y], axis="columns")
    combo["file_name"] = combo.id_video + ".jpg"
    datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
#                                  rotation_range=15,
#                                  width_shift_range=0.15,
#                                  height_shift_range=0.15,
#                                  zoom_range=0.2,
#                                  horizontal_flip=True,
#                                  dtype=np.float32
                                )
    gen = datagen.flow_from_dataframe(dataframe=combo,
                                      directory=img_dir,
                                      x_col="file_name", 
                                      y_col="qtl",
                                      class_mode="categorical",
                                      color_mode="rgb",
                                      target_size=(120, 90),
                                      shuffle=True,
                                      batch_size=batch_size                                      
                                     )
    return gen

def val_generator(X, y, img_dir, batch_size):
    combo = pd.concat([X, y], axis="columns")
    combo["file_name"] = combo.id_video + ".jpg"
    datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
    gen = datagen.flow_from_dataframe(dataframe=combo,
                                      directory=img_dir,
                                      x_col="file_name", 
                                      y_col="qtl",
                                      class_mode="categorical",
                                      color_mode="rgb",
                                      target_size=(120, 90),
                                      shuffle=True,
                                      batch_size=batch_size                                      
                                     )
    return gen

# %% [markdown]
# # Train the model

# %%
img_dir = "../images"
batch_size = 64

train_gen = train_generator(x_train, y_train, img_dir, batch_size)
val_gen = val_generator(x_val, y_val, img_dir, batch_size)

metric = "val_loss"

es = EarlyStopping(monitor=metric, 
                   mode="min", 
                   patience=5, 
                   restore_best_weights=True)

checkpoint = ModelCheckpoint(os.path.join(p_dir, "{}".format(m_name)), 
                             monitor=metric, 
                             verbose=2, 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='min')

hist = model.fit(train_gen,
                 epochs=200,
                 validation_data=val_gen,
                 verbose=1,
                 callbacks=[checkpoint, es])
# Out:
# Found 11586 validated image filenames belonging to 4 classes.
# Found 3862 validated image filenames belonging to 4 classes.
# Epoch 1/200
# 182/182 [==============================] - 12s 60ms/step - loss: 1.5083 - accuracy: 0.4647 - val_loss: 0.9197 - val_accuracy: 0.6015
#
# Epoch 00001: val_loss improved from inf to 0.91969, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 2/200
# 182/182 [==============================] - 10s 56ms/step - loss: 1.0983 - accuracy: 0.5628 - val_loss: 0.8371 - val_accuracy: 0.6416
#
# Epoch 00002: val_loss improved from 0.91969 to 0.83705, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 3/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.9676 - accuracy: 0.5986 - val_loss: 0.8085 - val_accuracy: 0.6569
#
# Epoch 00003: val_loss improved from 0.83705 to 0.80846, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 4/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.9016 - accuracy: 0.6205 - val_loss: 0.7901 - val_accuracy: 0.6618
#
# Epoch 00004: val_loss improved from 0.80846 to 0.79007, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 5/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.8663 - accuracy: 0.6351 - val_loss: 0.7718 - val_accuracy: 0.6748
#
# Epoch 00005: val_loss improved from 0.79007 to 0.77180, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 6/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.8327 - accuracy: 0.6470 - val_loss: 0.7590 - val_accuracy: 0.6820
#
# Epoch 00006: val_loss improved from 0.77180 to 0.75901, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 7/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.8049 - accuracy: 0.6628 - val_loss: 0.7460 - val_accuracy: 0.6888
#
# Epoch 00007: val_loss improved from 0.75901 to 0.74602, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 8/200
# 182/182 [==============================] - 11s 58ms/step - loss: 0.7838 - accuracy: 0.6708 - val_loss: 0.7386 - val_accuracy: 0.6926
#
# Epoch 00008: val_loss improved from 0.74602 to 0.73859, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 9/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.7729 - accuracy: 0.6784 - val_loss: 0.7315 - val_accuracy: 0.6976
#
# Epoch 00009: val_loss improved from 0.73859 to 0.73155, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 10/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.7573 - accuracy: 0.6858 - val_loss: 0.7204 - val_accuracy: 0.7025
#
# Epoch 00010: val_loss improved from 0.73155 to 0.72044, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 11/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.7421 - accuracy: 0.6912 - val_loss: 0.7131 - val_accuracy: 0.7020
#
# Epoch 00011: val_loss improved from 0.72044 to 0.71307, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 12/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.7339 - accuracy: 0.6955 - val_loss: 0.7062 - val_accuracy: 0.7105
#
# Epoch 00012: val_loss improved from 0.71307 to 0.70622, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 13/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.7182 - accuracy: 0.7011 - val_loss: 0.6987 - val_accuracy: 0.7157
#
# Epoch 00013: val_loss improved from 0.70622 to 0.69870, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 14/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.7046 - accuracy: 0.7164 - val_loss: 0.6935 - val_accuracy: 0.7152
#
# Epoch 00014: val_loss improved from 0.69870 to 0.69349, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 15/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.6893 - accuracy: 0.7178 - val_loss: 0.6921 - val_accuracy: 0.7134
#
# Epoch 00015: val_loss improved from 0.69349 to 0.69214, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 16/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.6852 - accuracy: 0.7196 - val_loss: 0.6826 - val_accuracy: 0.7204
#
# Epoch 00016: val_loss improved from 0.69214 to 0.68258, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 17/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.6741 - accuracy: 0.7233 - val_loss: 0.6810 - val_accuracy: 0.7180
#
# Epoch 00017: val_loss improved from 0.68258 to 0.68105, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 18/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.6637 - accuracy: 0.7308 - val_loss: 0.6737 - val_accuracy: 0.7204
#
# Epoch 00018: val_loss improved from 0.68105 to 0.67371, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 19/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.6503 - accuracy: 0.7357 - val_loss: 0.6727 - val_accuracy: 0.7253
#
# Epoch 00019: val_loss improved from 0.67371 to 0.67272, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 20/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.6423 - accuracy: 0.7419 - val_loss: 0.6702 - val_accuracy: 0.7206
#
# Epoch 00020: val_loss improved from 0.67272 to 0.67016, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 21/200
# 182/182 [==============================] - 10s 55ms/step - loss: 0.6296 - accuracy: 0.7468 - val_loss: 0.6645 - val_accuracy: 0.7276
#
# Epoch 00021: val_loss improved from 0.67016 to 0.66451, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 22/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.6158 - accuracy: 0.7563 - val_loss: 0.6631 - val_accuracy: 0.7299
#
# Epoch 00022: val_loss improved from 0.66451 to 0.66312, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 23/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.6127 - accuracy: 0.7535 - val_loss: 0.6629 - val_accuracy: 0.7253
#
# Epoch 00023: val_loss improved from 0.66312 to 0.66290, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 24/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.5986 - accuracy: 0.7619 - val_loss: 0.6558 - val_accuracy: 0.7367
#
# Epoch 00024: val_loss improved from 0.66290 to 0.65575, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 25/200
# 182/182 [==============================] - 10s 54ms/step - loss: 0.5873 - accuracy: 0.7640 - val_loss: 0.6528 - val_accuracy: 0.7323
#
# Epoch 00025: val_loss improved from 0.65575 to 0.65277, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 26/200
# 182/182 [==============================] - 10s 54ms/step - loss: 0.5790 - accuracy: 0.7735 - val_loss: 0.6502 - val_accuracy: 0.7302
#
# Epoch 00026: val_loss improved from 0.65277 to 0.65023, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 27/200
# 182/182 [==============================] - 10s 55ms/step - loss: 0.5706 - accuracy: 0.7736 - val_loss: 0.6511 - val_accuracy: 0.7323
#
# Epoch 00027: val_loss did not improve from 0.65023
# Epoch 28/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.5457 - accuracy: 0.7837 - val_loss: 0.6551 - val_accuracy: 0.7317
#
# Epoch 00028: val_loss did not improve from 0.65023
# Epoch 29/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.5636 - accuracy: 0.7777 - val_loss: 0.6529 - val_accuracy: 0.7354
#
# Epoch 00029: val_loss did not improve from 0.65023
# Epoch 30/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.5500 - accuracy: 0.7843 - val_loss: 0.6473 - val_accuracy: 0.7325
#
# Epoch 00030: val_loss improved from 0.65023 to 0.64732, saving model to ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2
# INFO:tensorflow:Assets written to: ../img models/mobilenet_4_classes_2/mobilenet_4_classes_2/assets
# Epoch 31/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.5333 - accuracy: 0.7891 - val_loss: 0.6525 - val_accuracy: 0.7302
#
# Epoch 00031: val_loss did not improve from 0.64732
# Epoch 32/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.5188 - accuracy: 0.7972 - val_loss: 0.6576 - val_accuracy: 0.7349
#
# Epoch 00032: val_loss did not improve from 0.64732
# Epoch 33/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.5204 - accuracy: 0.7978 - val_loss: 0.6545 - val_accuracy: 0.7382
#
# Epoch 00033: val_loss did not improve from 0.64732
# Epoch 34/200
# 182/182 [==============================] - 10s 57ms/step - loss: 0.5003 - accuracy: 0.8058 - val_loss: 0.6649 - val_accuracy: 0.7336
#
# Epoch 00034: val_loss did not improve from 0.64732
# Epoch 35/200
# 182/182 [==============================] - 10s 56ms/step - loss: 0.5130 - accuracy: 0.8065 - val_loss: 0.6574 - val_accuracy: 0.7317
#
# Epoch 00035: val_loss did not improve from 0.64732

# %%
fig, axs = plt.subplots(1, 2)

axs[0].plot(hist.history["accuracy"])
axs[0].plot(hist.history["val_accuracy"])
axs[0].set_title("model accuracy")
axs[0].set_ylabel("accuracy")
axs[0].set_xlabel("epoch")
axs[0].set_ylim(0, 1)
axs[0].legend(["train", "val"], loc="upper left")

axs[1].plot(hist.history["loss"])
axs[1].plot(hist.history["val_loss"])
axs[1].set_title("model loss")
axs[1].set_ylabel("loss")
axs[1].set_xlabel("epoch")
# axs[1].set_ylim(0, 1)
axs[1].legend(["train", "val"], loc="upper left")

plt.tight_layout()
plt.show()
fig.savefig(os.path.join(p_dir, "accuracy_loss.jpg"))

# %% [markdown]
# # Sample images per category

# %%
s = combo.loc[combo["id_video"].isin(x_train["id_video"]), ["id_video", "qtl"]].groupby("qtl", as_index=False).apply(lambda x: x.sample(5, random_state=15))

fig, axs = plt.subplots(len(cat_lbl), 5)
i = 0
for idx, row in s.iterrows():
    img = Image.open(os.path.join(img_dir, "{}.jpg".format(row["id_video"])))
    axs[i // 5, i % 5].imshow(img)
    axs[i // 5, i % 5].xaxis.set_ticklabels([])
    axs[i // 5, i % 5].xaxis.set_ticks([])
    axs[i // 5, i % 5].set_xlabel(row["qtl"])
    axs[i // 5, i % 5].yaxis.set_ticklabels([])
    axs[i // 5, i % 5].yaxis.set_ticks([])
    i += 1
plt.tight_layout()
plt.show()
fig.savefig(os.path.join(p_dir, "sample_images.jpg"))

# %% [markdown]
# # Confusion matrix

# %%
model = load_model(os.path.join(p_dir, "{}".format(m_name)))

# %%
def test_generator(X, y, img_dir):
    combo = pd.concat([X, y], axis="columns")
    combo["file_name"] = combo.id_video + ".jpg"
    datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
    gen = datagen.flow_from_dataframe(dataframe=combo,
                                      directory=img_dir,
                                      x_col="file_name", 
                                      y_col="qtl",
                                      class_mode="categorical",
                                      color_mode="rgb",
                                      target_size=(120, 90),
                                      shuffle=False,
                                      batch_size=1                                      
                                     )
    return gen

# %%
img_dir = "../images"

x_test = pd.read_pickle(os.path.join(p_dir, "x_test.pkl"))
y_test = pd.read_pickle(os.path.join(p_dir, "y_test.pkl"))
test_gen = test_generator(x_test, y_test, img_dir)
y_pred = model.predict(test_gen, steps=y_test.shape[0])
y_pred = np.argmax(y_pred, axis=1)
cls_lbl = dict([(v, k) for k, v in test_gen.class_indices.items()])
y_pred = pd.Series([cls_lbl[i] for i in y_pred]).astype("category").cat.reorder_categories(cat_lbl)
# Out:
# Found 3863 validated image filenames belonging to 4 classes.

# %%
cmtx = confusion_matrix(y_test, y_pred)
sb.heatmap(cmtx, annot=True, fmt="d", xticklabels=y_test.cat.categories, yticklabels=y_pred.cat.categories)
plt.xlabel("True class")
plt.ylabel("Predicted class")
plt.title("Confusion matrix")
plt.show()
plt.savefig(os.path.join(p_dir, "confusion_matrix.jpg"))
plt.show()

print("Accuracy: {:0.2f}".format(accuracy_score(y_test, y_pred)))

print("Micro precision: {:0.2f}".format(precision_score(y_test, y_pred, average="micro")))
print("Micro recall: {:0.2f}".format(recall_score(y_test, y_pred, average="micro")))
print("Micro F1-score: {:0.2f}".format(f1_score(y_test, y_pred, average="micro")))

print("Macro precision: {:0.2f}".format(precision_score(y_test, y_pred, average="macro")))
print("Macro recall: {:0.2f}".format(recall_score(y_test, y_pred, average="macro")))
print("Macro F1-score: {:0.2f}".format(f1_score(y_test, y_pred, average="macro")))

print("Weighted precision: {:0.2f}".format(precision_score(y_test, y_pred, average="weighted")))
print("Weighted recall: {:0.2f}".format(recall_score(y_test, y_pred, average="weighted")))
print("Weighted F1-score: {:0.2f}".format(f1_score(y_test, y_pred, average="weighted")))

print(classification_report(y_test, y_pred, target_names=cat_lbl))
# Out:
# Accuracy: 0.74
# Micro precision: 0.74
# Micro recall: 0.74
# Micro F1-score: 0.74
# Macro precision: 0.75
# Macro recall: 0.74
# Macro F1-score: 0.74
# Weighted precision: 0.75
# Weighted recall: 0.74
# Weighted F1-score: 0.74
#               precision    recall  f1-score   support
#
#     very low       0.79      0.71      0.75      1053
#          low       0.62      0.75      0.68       954
#         high       0.89      0.84      0.87       892
#    very high       0.69      0.67      0.68       964
#
#     accuracy                           0.74      3863
#    macro avg       0.75      0.74      0.74      3863
# weighted avg       0.75      0.74      0.74      3863

# %% [markdown]
# # Grad-CAM class activation visualization

# %%
def get_img_array(img_path, size):
    img = load_img(img_path, target_size=size)
    array = img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    grads = tape.gradient(class_channel, last_conv_layer_output)

    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def create_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    img = load_img(img_path)
    img = img_to_array(img)

    heatmap = np.uint8(255 * heatmap)

    jet = cm.get_cmap("jet")

    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    jet_heatmap = array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = img_to_array(jet_heatmap)

    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = array_to_img(superimposed_img)

    return superimposed_img

# %%
def cam_image(img_dir, id_video, last_cl, alpha=0.4):
    img_path = os.path.join(img_dir, "{}.jpg".format(row["id_video"]))
    img_array = get_img_array(img_path, size=(120, 90))
    model.layers[-1].activation = None
    preds = model.predict(img_array)
    heatmap = make_gradcam_heatmap(img_array, model, last_cl)
    img = create_gradcam(img_path, heatmap, os.path.join(p_dir, "cam_{}.jpg".format(row["id_video"])), alpha)
    return img

# %%
p = re.compile("conv_pw_\d+$")
p2 = re.compile("conv_pw_(\d+)$")
conv_layers = list()
for layer in model.layers:
    if p.match(layer.name):
        conv_layers.append(layer.name)

# %%
target_names = conv_layers
for layer in model.layers:
    if layer.name in target_names:        
        alpha = 0.8

        fig, axs = plt.subplots(len(cat_lbl), 5)
        i = 0
        for idx, row in s.iterrows():
            img_path = os.path.join(img_dir, "{}.jpg".format(row["id_video"]))
            img = cam_image(img_dir, row["id_video"], layer.name, alpha)
            axs[i // 5, i % 5].imshow(img)
            axs[i // 5, i % 5].xaxis.set_ticklabels([])
            axs[i // 5, i % 5].xaxis.set_ticks([])
            axs[i // 5, i % 5].set_xlabel(row["qtl"])
            axs[i // 5, i % 5].yaxis.set_ticklabels([])
            axs[i // 5, i % 5].yaxis.set_ticks([])
            i += 1
        plt.suptitle("Layer: {}".format(layer.name))
        plt.tight_layout()        
        plt.show()
        fig.savefig(os.path.join(p_dir, "cam_sample_{}.jpg".format(layer.name)))
